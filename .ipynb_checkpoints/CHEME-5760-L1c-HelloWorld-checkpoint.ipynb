# %% [markdown]
# # Lab 1c: Hello World
#
# The objective of this lab is to load some of the packages that will be required for the other labs throughout the semester and to test your installs. If everything works, we should see a sample histogram of a `standard Normal distribution` overlaid on a plot of the analytical density function.

# %%
include("Include.jl")
# Out:
#   Activating project at `~/Desktop/julia_work/CHEME-5760-Labs-F23`
#     Updating registry at `~/.julia/registries/General.toml`
#     Updating git-repo `https://github.com/varnerlab/VLDecisionsPackage.jl.git`
#   No Changes to `~/Desktop/julia_work/CHEME-5760-Labs-F23/Project.toml`
#   No Changes to `~/Desktop/julia_work/CHEME-5760-Labs-F23/Manifest.toml`
# [ Info: Precompiling StatsPlots [f3b207a7-027a-5e70-b257-86293d7955fd]
# ┌ Warning: Module Plots with build ID fafbfcfd-dd7c-efde-0000-6794bbf3890b is missing from the cache.
# │ This may mean Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1793
# [ Info: Skipping precompilation since __precompile__(false). Importing StatsPlots [f3b207a7-027a-5e70-b257-86293d7955fd].
# [ Info: Precompiling Clustering [aaaa29a8-35af-508c-8bc3-b662a17a0fe5]
# [ Info: Precompiling FiniteDiffStaticArraysExt [75e56524-3a34-51de-85ea-03aa6eac4b64]
# ...

# %%
# create a standard normal distribution -
d = Normal(0,1);

# %%
# plot the analytical distribution -
plot(d, lw=3, color=:red, label="Density N(0,1) Analytical", xlabel="x-value", ylabel="Frequency")

# %%
# sample -
Nₛ = 25000
S = rand(d, Nₛ);

# %%
# plot -
histogram!(S, label="Density N(0,1) Sampled", xlabel="x-value", ylabel="Frequency", normed=true, color=:blue)
